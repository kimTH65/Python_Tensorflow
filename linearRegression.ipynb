# %%
import tensorflow as tf # 구글사, 딥러닝 라이브러리
import numpy as np # 다차원 배열, 수치해석, 계산용 Python 패키지

# %%
# x_data 와 y_data의 상관관계를 알아보는 알고리즘(선형회귀)
x_data = [1,2,3]
y_data = [1,2,3]

# %%
#tensorFlow V1.0
#W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
#b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

#tensorFlow V2.0  / -1.0부터1.0 사이 균등분포(uniform distribution)를 가진 무작위 값으로 초기화
W = tf.Variable(tf.random.uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random.uniform([1], -1.0, 1.0))

# %%
#tensorFlow V1.0
#X = tf.placeholder(tf.float32, name="X")
#Y = tf.placeholder(tf.float32, name="Y")

#tensorFlow V2.0 / don't use session,placeholder
X = tf.Variable(tf.zeros(shape=(1)), name="X") # tf.zeros : 모든 원소 0로 설정
Y = tf.Variable(tf.ones(shape=(1)), name="Y") # tf.zeros : 모든 원소 1로 설정

# %%
hypothesis = W * X + b #  X,Y의 상관관계를 분석하기 위한 수식 / W 가중치 , b 편향값 / Y = WX +b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y)) # 손실함수 / 예측값(hypothesis) - 실제값(Y) 을 제곱(square) 하여 
                                                 # 평균(reduce_mean)을 구한다

#tensorFlow V1.0 - optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
sgd = tf.keras.optimizers.SGD (learning_rate=0.01)# keras : 딥러닝 API 
                                                  # optimizers : 손실 함수를 통해 얻은 손실값으로부터 모델을 업데이트 하는 방식
                                                  # SGD : 경사하강법(운동량 포함) 최적화 프로그램
                                                  # learning_rate : 학습률 
            
model = tf.keras.models.Sequential() # Sequential model :  정확히 하나의 입력 텐서와 하나의 출력 텐서가 있는 레이어에 적합

model.add(tf.keras.layers.Dense(1, input_dim=1)) # 조밀하게(dense)연결된 일반 뉴런 네트워크(NN) 레이어 
                                                 # (출력 뉴런수, 입력 뉴런수(input_dim))
    
model.compile(loss = 'mean_squared_error', optimizer=sgd) # loss : 손실함수 / mean_squared_error : 평균 제곱 오차
model.fit(x_data, y_data, epochs=100) # epochs 데이터를 얼마나 반복할 것인가
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 315ms/step - loss: 1.3681
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0826
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8569
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6785
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5375
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4260
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3379
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2682
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2131
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1696
# Epoch 11/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1352
# Epoch 12/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1080
# Epoch 13/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0864
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0694
# Epoch 15/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0560
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0453
# Epoch 17/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0369
# Epoch 18/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0303
# Epoch 19/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0250
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0208
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 22/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0149
# Epoch 23/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129
# Epoch 24/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0112
# Epoch 25/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0099
# Epoch 26/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0089
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0081
# Epoch 28/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 29/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 30/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0061
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0059
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0055
# Epoch 35/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0053
# Epoch 36/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 40/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 44/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 45/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 46/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 47/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 48/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 49/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 50/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 51/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 52/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 53/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 54/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0044
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 56/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0044
# Epoch 57/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0044
# Epoch 58/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 59/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 60/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 61/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 62/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 63/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 64/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0042
# Epoch 65/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 66/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 67/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 68/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 69/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 70/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 71/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 72/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 73/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 74/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 76/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 79/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 81/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 82/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 83/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 84/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 85/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 86/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 87/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0038
# Epoch 89/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 90/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 91/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 92/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 93/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 95/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 96/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 97/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 98/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 99/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 100/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0035

# %%
print(model.predict(np.array([1]))) # 예측하기
# Out:
# [[0.9121382]]
